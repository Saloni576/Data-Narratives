# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #Q1] Is there a significant correlation between a player's first serve percentage and their second serve percentage in tennis matches?

# %%
df = pd.read_csv("/content/AusOpen-men-2013.csv")
df.head()
# Out:
#             Player1          Player2  Round  Result  FNL1  FNL2  FSP.1  FSW.1  \
# 0       Lukas Lacko   Novak Djokovic      1       0     0     3     61     35
# 1    Leonardo Mayer  Albert Montanes      1       1     3     0     61     31
# 2  Marcos Baghdatis    Denis Istomin      1       0     0     3     52     53
# 3   Dmitry Tursunov  Michael Russell      1       1     3     0     53     39
# 4       Juan Monaco   Ernests Gulbis      1       0     1     3     76     63
#
#    SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  ST2.2  ST3.2  \
# 0     39     18  ...      4      8    8.0    9.0    101      6    7.0    6.0
# 1     39     13  ...      0      0    NaN    NaN     42      1    3.0    1.0
# 2     48     20  ...      4     13   12.0   16.0    126      6    7.0    6.0
# 3     47     24  ...      1      7    NaN    NaN     79      2    2.0    3.0
# 4     24     12  ...      3      5   16.0   28.0    127      1    6.0    7.0
#
#    ST4.2  ST5.2
# 0    NaN    NaN
# ...

# %%
sns.regplot(x="FSP.1", y="SSP.1", data=df)
sns.scatterplot(x="FSP.1", y="SSP.1", data=df, color="red")
plt.title("Player 1")
plt.show()

sns.regplot(x="FSP.2", y="SSP.2", data=df)
sns.scatterplot(x="FSP.2", y="SSP.2", data=df, color="red")
plt.title("Player 2")
plt.show()

# %% [markdown]
# # Q2] What is the average number of break points created by players in a tennis match?

# %%
data = pd.read_csv("/content/AusOpen-women-2013.csv")
data["BPC.1"], data["BPW.1"] = data["BPW.1"], data["BPC.1"]
data["BPC.2"], data["BPW.2"] = data["BPW.2"], data["BPC.2"]
data["NPA.1"], data["NPW.1"] = data["NPW.1"], data["NPA.1"]
data["NPA.2"], data["NPW.2"] = data["NPW.2"], data["NPA.2"]
data.head()
# Out:
#               Player1             Player2  Round  Result  FNL1  FNL2  FSP.1  \
# 0     Serena Williams      Ashleigh Barty      1       1   2.0   0.0     59
# 1        Vesna Dolonc   Lara Arruabarrena      1       1   2.0   1.0     65
# 2  Pauline Parmentier   Karolina Pliskova      1       0   0.0   2.0     63
# 3      Heather Watson  Daniela Hantuchova      1       0   1.0   2.0     61
# 4     Samantha Stosur    Klara Zakopalova      1       1   2.0   0.0     65
#
#    FSW.1  SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  ST2.2  \
# 0     20     41      8  ...    0.0    0.0    4.0    2.0     31    2.0    1.0
# 1     33     35     10  ...    7.0    4.0    NaN    NaN     74    6.0    2.0
# 2     16     37      4  ...   14.0    5.0    NaN    NaN     64    6.0    6.0
# 3     41     39     19  ...   13.0    5.0    8.0    5.0    102    7.0    3.0
# 4     28     35     11  ...   14.0    4.0   15.0   10.0     60    3.0    4.0
#
#    ST3.2  ST4.2  ST5.2
# ...

# %%
total_bpc = data["BPC.1"] + data["BPC.2"]
avg_bpc = total_bpc.mean()
print("Average number of break points created per match:", avg_bpc)

plt.hist(total_bpc, bins=20, color='green')
plt.axvline(avg_bpc, color='red', linestyle='dashed', linewidth=2)
plt.xlabel("Break points created")
plt.ylabel("Number of matches")
plt.title("Distribution of break points created by players")
plt.show()
# Out:
# Average number of break points created per match: 16.396825396825395

# %% [markdown]
# # Q3] Does a higher number of aces won by a player in a tennis match correspond to a higher probability of winning the match?

# %%
data = pd.read_csv("/content/FrenchOpen-men-2013.csv")
data.head()
# Out:
#                Player1                  Player2  Round  Result  FNL.1  FNL.2  \
# 0  Pablo Carreno-Busta            Roger Federer      1       0      0      3
# 1     Somdev Devvarman  Daniel Munoz-De La Nava      1       1      3      0
# 2         Tobias Kamke            Paolo Lorenzi      1       1      3      2
# 3     Julien Benneteau        Ricardas Berankis      1       1      3      1
# 4          Lukas Lacko              Sam Querrey      1       0      0      3
#
#    FSP.1  FSW.1  SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  \
# 0     62     27     38     11  ...      7      7     14     18     88      6
# 1     62     54     38     22  ...      1     16     22     25    106      3
# 2     62     53     38     15  ...     10     18     19     27    139      3
# 3     72     87     28     19  ...      4     13     33     43    149      6
# 4     52     31     48     22  ...      4      7     12     13     93      6
#
#    ST2.2  ST3.2  ST4.2  ST5.2
# ...

# %%
winner_aces_df = data.loc[data['Result'] == 1, ['ACE.1']]
loser_aces_df = data.loc[data['Result'] == 0, ['ACE.2']]

avg_aces_winner = winner_aces_df.mean()[0]
avg_aces_loser = loser_aces_df.mean()[0]

plt.hist(winner_aces_df['ACE.1'], bins=20, alpha=0.5, label='Winner')
plt.hist(loser_aces_df['ACE.2'], bins=20, alpha=0.5, label='Loser')
plt.axvline(x=avg_aces_winner, color='blue', label='Avg. Aces Won by Winner')
plt.axvline(x=avg_aces_loser, color='orange', label='Avg. Aces Won by Loser')
plt.xlabel('Aces Won')
plt.ylabel('Frequency')
plt.title('Distribution of Aces Won by Winner and Loser')
plt.legend()
plt.show()

# %% [markdown]
# # Q4] What is the impact of winning or losing Set 1 on the outcome of a tennis match for a player?

# %%
data = pd.read_csv("/content/FrenchOpen-women-2013.csv")
data.head()
# Out:
#             Player1             Player2  Round  Result  FNL.1  FNL.2  FSP.1  \
# 0      Su-Wei Hsieh     Maria Sharapova      1       0      0      2     62
# 1  Eugenie Bouchard  Tsvetana Pironkova      1       1      2      0     57
# 2         Jie Zheng        Vesna Dolonc      1       1      2      0     76
# 3     Tamira Paszek       Melanie Oudin      1       0      0      2     59
# 4       Karin Knapp     Sloane Stephens      1       0      0      2     57
#
#    FSW.1  SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  ST2.2  \
# 0     18     38      5  ...      4      6      3      5     57      6    6.0
# 1     23     43     17  ...      1      3      4      8     48      1    6.0
# 2     30     24      5  ...      0      4     14     20     56      4    1.0
# 3     16     41      8  ...      8     13      5      8     78      6    6.0
# 4     18     43     13  ...      5      7      1      4     61      6    7.0
#
#    ST3.2  ST4.2  ST5.2
# ...

# %%
set1_df = data[['ST1.1', 'ST1.2', 'Result']].copy()
set1_df.dropna(inplace=True)
set1_df['Set1_winner'] = set1_df.apply(lambda x: x['ST1.1'] if x['Result'] == 1
                                       else x['ST1.2'], axis=1)
set1_df['Set1_loser'] = set1_df.apply(lambda x: x['ST1.2'] if x['Result'] == 1
                                      else x['ST1.1'], axis=1)
set1_df['Set1_winner_win'] = set1_df.apply(lambda x: 1
                                           if x['Set1_winner'] > x['Set1_loser']
                                           else 0, axis=1)
set1_win_percentage = set1_df.groupby('Set1_winner_win').size().div(len(set1_df)).mul(100).round(2)
labels = ['Lost Set 1', 'Won Set 1']
values = set1_win_percentage.values

plt.bar(labels, values, color="#DC143C")
plt.xlabel('Set 1 Result')
plt.ylabel('Percentage of Matches Won')
plt.title('Impact of Winning/Losing Set 1 on Match Outcome')
plt.show()

# %% [markdown]
# # Q5] How does the number of double faults committed by the loser of a tennis match compare to the average number of double faults in a match?

# %%
data = pd.read_csv("/content/USOpen-men-2013.csv")
data.head()
# Out:
#               Player1          Player2  Round  Result  FNL1  FNL2  FSP.1  \
# 0     Richard Gasquet  Michael Russell      1       1     3     0     63
# 1     Stephane Robert  Albano Olivetti      1       1     3     0     61
# 2  Jan-Lennard Struff  Guillaume Rufin      1       0     2     3     55
# 3        Aljaz Bedene  Dmitry Tursunov      1       0     1     3     52
# 4     Feliciano Lopez    Florent Serra      1       1     3     1     58
#
#    FSW.1  SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  ST2.2  \
# 0     45     37     16  ...      1      3   30.0   40.0     83      3      4
# 1     44     39     19  ...      0      1    NaN    NaN     71      3      3
# 2     61     45     32  ...      5     15    NaN    NaN    149      7      6
# 3     41     48     19  ...      6      9    NaN    NaN    121      7      4
# 4     54     42     30  ...      0      3    NaN    NaN    123      7      2
#
#    ST3.2  ST4.2  ST5.2
# 0    2.0    NaN    NaN
# ...

# %%
loser_df = data[['DBF.2']][data['Result'] == 0]

avg_df_match = data['DBF.1'].mean()
avg_df_loser = loser_df.mean()
colors = ['#FFC300', '#C70039']

plt.hist([data['DBF.1'].dropna(), loser_df['DBF.2'].dropna()], bins=20,
         alpha=0.8, label=['Overall', 'Loser'], color=colors)
plt.axvline(x=avg_df_match, color='#EEAD0E', label='Avg. Double Faults in Match')
plt.axvline(x=avg_df_loser[0], color='#FF3030', label='Avg. Double Faults by Loser')
plt.xlabel('Double Faults')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# # Q6] Is there a correlation between the number of net points attempted and the number of net points won by a player in a tennis match?

# %%
data = pd.read_csv('/content/USOpen-women-2013.csv')
data.head()
# Out:
#        Player 1    Player 2  ROUND  Result  FNL.1  FNL.2  FSP.1  FSW.1  SSP.1  \
# 0    S Williams  V Azarenka      7       1      2      1     57     44     43
# 1    F Pennetta  V Azarenka      6       0      0      2     44     12     56
# 2    S Williams        N Li      6       1      2      0     63     26     37
# 3       R Vinci  F Pennetta      5       0      0      2     60     21     40
# 4  D Hantuchova  V Azarenka      5       0      0      2     58     14     42
#
#    SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST2.1.1  ST2.2  ST3.2  \
# 0     20  ...      8      4   15.0   10.0    NaN        5      7    1.0
# 1      7  ...     13      8   30.0   20.0    NaN        6      6    NaN
# 2      9  ...      4      1   19.0   13.0    NaN        0      3    NaN
# 3      7  ...     12      6   14.0    7.0    NaN        6      6    NaN
# 4      5  ...     11      7   13.0   12.0    NaN        6      6    NaN
#
#    ST4.2  ST5.2
# 0    NaN    NaN
# 1    NaN    NaN
# ...

# %%
winner_net_points = data[['NPW.1', 'NPA.1']]

corr = winner_net_points.corr()

plt.scatter(winner_net_points['NPA.1'], winner_net_points['NPW.1'], color='purple')
plt.plot(winner_net_points['NPA.1'],
         winner_net_points['NPA.1']*corr.iloc[0,1] - corr.iloc[0,0], color='orange')
plt.xlabel('Net Points Attempted')
plt.ylabel('Net Points Won')
plt.title('Relationship between Net Points Attempted and Won by Winner')
plt.show()

# %% [markdown]
# # Q7] Does the round of a tennis tournament have an impact on the number of winners earned by players in a match?

# %%
data = pd.read_csv('/content/Wimbledon-men-2013.csv')
data.tail()
# Out:
#         Player1      Player2  Round  Result  FNL.1  FNL.2  FSP.1  FSW.1  \
# 109    D.Ferrer  J.Del Potro      5       0      0      3     68     45
# 110  N.Djokovic    T.Berdych      5       1      3      0     61     42
# 111  J.Janowicz     A.Murray      6       0      1      3     55     54
# 112  N.Djokovic  J.Del Potro      6       1      3      2     69    102
# 113  N.Djokovic     A.Murray      7       0      0      3     65     40
#
#      SSP.1  SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.2  ST2.2  \
# 109     32     17  ...      8      3     21     17    NaN      6      6
# 110     39     21  ...      2      2     31     21    NaN      6      4
# 111     45     27  ...     13      5     36     22    NaN      6      6
# 112     31     21  ...      7      2     37     25    NaN      5      6
# 113     35     15  ...     17      7     37     26    NaN      6      7
#
#      ST3.2  ST4.2  ST5.2
# 109      7    NaN    NaN
# 110      3    NaN    NaN
# ...

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='Round',
                 y=data['WNR.1']+data['WNR.2'], data=data, palette='husl')
plt.title('Winners earned by players in each round')
plt.xlabel('Round')
plt.ylabel('Number of winners')
plt.show()

# %% [markdown]
# # Q8] Does the outcome of Set 1 have any influence on the outcome of Set 3 in a tennis match?

# %%
tennis_data = pd.read_csv("/content/Wimbledon-women-2013.csv")
tennis_data.head()
# Out:
#         Player1     Player2  Round  Result  FNL.1  FNL.2  FSP.1  FSW.1  SSP.1  \
# 0     M.Koehler  V.Azarenka      1       0      0      2     60     21     40
# 1    E.Baltacha  F.Pennetta      1       0      0      2     69     23     31
# 2     S-W.Hsieh     T.Maria      1       1      2      0     63     17     37
# 3      A.Cornet      V.King      1       1      2      1     57     36     43
# 4  Y.Putintseva  K.Flipkens      1       0      0      2     73     34     27
#
#    SSW.1  ...  BPC.2  BPW.2  NPA.2  NPW.2  TPW.2  ST1.1.1  ST2.2  ST3.2  \
# 0      8  ...     16      6      8      4    NaN        6      6    NaN
# 1      6  ...      6      5     14     11    NaN        6      6    NaN
# 2     10  ...      1      0      8      2    NaN        1      0    NaN
# 3     21  ...      4      1     48     32    NaN        6      3    1.0
# 4     12  ...      9      3     35     24    NaN        7      6    NaN
#
#    ST4.2  ST5.2
# 0    NaN    NaN
# 1    NaN    NaN
# ...

# %%
sns.regplot(x='ST1.1', y='ST3.1', data=tennis_data, ci=None, color="#FF34B3")
sns.scatterplot(x='ST1.1', y='ST3.1', data=tennis_data, color="#607B8B")
plt.show()
